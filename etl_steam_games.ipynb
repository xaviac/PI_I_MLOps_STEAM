# %%
# Bibliotecas a utilizar
import pandas as pd
import numpy as np
import json

# %%
# Se guarda el path del json en una variable
sg_path = 'data/raw/steam_games.json.gz'

# %%
df_steam_games = pd.read_json(sg_path, compression='gzip', lines=True)

df_steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120445 entries, 0 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 11.9+ MB

# %%
# Se elimina toda fila con datos competamente nulos
df_steam_games.dropna(how='all', inplace=True)

df_steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32135 entries, 88310 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     24083 non-null  object
#  1   genres        28852 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         30085 non-null  object
#  4   url           32135 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31972 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30758 non-null  object
#  10  early_access  32135 non-null  float64
#  11  id            32133 non-null  float64
#  12  developer     28836 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 3.4+ MB

# %%
# Hay que averiguar que tipo de datos tiene 'publisher'
df_steam_games['publisher'].apply(lambda x: type(x)).value_counts()
# Out:
# publisher
# <class 'str'>         24083
# <class 'NoneType'>     8052
# Name: count, dtype: int64

# %%
# Se utiliza un for para recorrer cada columna y saber que tipos de datos tienen
for c in df_steam_games:
    print(c, df_steam_games[c].apply(lambda x: type(x)).value_counts())
# Out:
# publisher publisher
# <class 'str'>         24083
# <class 'NoneType'>     8052
# Name: count, dtype: int64
# genres genres
# <class 'list'>        28852
# <class 'NoneType'>     3283
# Name: count, dtype: int64
# app_name app_name
# <class 'str'>         32133
# <class 'NoneType'>        2
# Name: count, dtype: int64
# title title
# <class 'str'>         30085
# <class 'NoneType'>     2050
# Name: count, dtype: int64
# url url
# <class 'str'>    32135
# Name: count, dtype: int64
# release_date release_date
# <class 'str'>         30068
# <class 'NoneType'>     2067
# Name: count, dtype: int64
# tags tags
# <class 'list'>        31972
# <class 'NoneType'>      163
# Name: count, dtype: int64
# reviews_url reviews_url
# <class 'str'>         32133
# <class 'NoneType'>        2
# Name: count, dtype: int64
# specs specs
# <class 'list'>        31465
# <class 'NoneType'>      670
# Name: count, dtype: int64
# price price
# <class 'float'>       28848
# <class 'str'>          1910
# <class 'NoneType'>     1377
# Name: count, dtype: int64
# early_access early_access
# <class 'float'>    32135
# Name: count, dtype: int64
# id id
# <class 'float'>    32135
# Name: count, dtype: int64
# developer developer
# <class 'str'>         28836
# <class 'NoneType'>     3299
# Name: count, dtype: int64

# %%
# Tomemos una muestra del dataframe
df_steam_games.sample(5)
# Out:
#                        publisher                      genres  \
# 118759  Wizards of the Coast LLC                  [Strategy]
# 107945                      None                        None
# 96425                    Ubisoft            [Action, Sports]
# 119532              Zeboyd Games                [RPG, Indie]
# 106891              @unepic_fran  [Action, Adventure, Indie]
#
#                                      app_name  \
# 118759   Magic 2013 "Berserker Rage" Deck Key
# 107945                             Quick Draw
# 96425                                  Steep™
# 119532                    Breath of Death VII
# 106891  Ghost 1.0 - Support Mission Mode Skin
#
#                                         title  \
# 118759   Magic 2013 "Berserker Rage" Deck Key
# 107945                                   None
# 96425                                  Steep™
# 119532                    Breath of Death VII
# 106891  Ghost 1.0 - Support Mission Mode Skin
#
#                                                       url release_date  \
# 118759  http://store.steampowered.com/app/208837/Magic...   2012-12-19
# 107945  http://store.steampowered.com/app/522250/Quick...         None
# 96425     http://store.steampowered.com/app/460920/Steep/   2016-12-02
# 119532  http://store.steampowered.com/app/107300/Breat...   2011-07-13
# 106891  http://store.steampowered.com/app/614080/Ghost...   2017-03-24
#
#                                                      tags  \
# 118759                                         [Strategy]
# 107945                                       [Action, VR]
# 96425   [Sports, Open World, Multiplayer, Action, Simu...
# 119532  [RPG, Indie, Comedy, JRPG, Retro, Pixel Graphi...
# 106891                         [Action, Adventure, Indie]
#
#                                               reviews_url  \
# 118759  http://steamcommunity.com/app/208837/reviews/?...
# 107945  http://steamcommunity.com/app/522250/reviews/?...
# 96425   http://steamcommunity.com/app/460920/reviews/?...
# 119532  http://steamcommunity.com/app/107300/reviews/?...
# 106891  http://steamcommunity.com/app/614080/reviews/?...
#
#                                                     specs  price  \
# 118759  [Single-player, Multi-player, Co-op, Shared/Sp...   0.99
# 107945  [Single-player, Online Multi-Player, Steam Ach...   9.99
# 96425   [Single-player, Online Multi-Player, Steam Tra...  29.99
# 119532           [Single-player, Full controller support]   2.99
# 106891  [Single-player, Downloadable Content, Steam Ac...   1.99
#
#         early_access        id  \
# 118759           0.0  208837.0
# 107945           0.0  522250.0
# 96425            0.0  460920.0
# 119532           0.0  107300.0
# 106891           0.0  614080.0
#
#                                               developer
# 118759                                  Stainless Games
# 107945                                             None
# 96425   Ubisoft Annecy,Ubisoft Montpellier,Ubisoft Kiev
# 119532                                     Zeboyd Games
# 106891                                     @unepic_fran

# %%
# Las columnas 'genres' y 'tags' son muy similares y ambas tienen datos nulos que podrían complementarse.
print('Cantidad de valores núlos en la columna "genres" ',df_steam_games['genres'].isna().sum())
print('\nCantidad de valores núlos en la columna "tags" ',df_steam_games['tags'].isna().sum())
# Out:
# Cantidad de valores núlos en la columna "genres"  3283
#
# Cantidad de valores núlos en la columna "tags"  163

# %%
# Considerando la información de datos nulos en 'tags' y 'genres', se observa que la información es muy similar entre ambas columnas
# Por lo que se ocupará a información de 'tags' para rellenar la columna 'genres' y viceversa
df_steam_games['genres'].fillna(df_steam_games['tags'], inplace=True)
df_steam_games['tags'].fillna(df_steam_games['genres'], inplace=True)

# %%
# De los 3283 datos nulos de 'genres' y los 163 de 'tags' solamente quedaron 139 que aun siguen nulos en ambas columnas
print('Cantidad de valores núlos en la columna "genres" ',df_steam_games['genres'].isna().sum())
print('\nCantidad de valores núlos en la columna "tags" ',df_steam_games['tags'].isna().sum())
# Out:
# Cantidad de valores núlos en la columna "genres"  139
#
# Cantidad de valores núlos en la columna "tags"  139

# %%
# Mostrar filas que tienen valores nulos en genres y tags
df_steam_games[df_steam_games['genres'].isna() | df_steam_games['tags'].isna()]
# Out:
#                                                 publisher genres  \
# 88384                                                None   None
# 88668                                 Paradox Interactive   None
# 88779                                     DnS Development   None
# 88922                 SEGA, Feral Interactive (Mac/Linux)   None
# 89089                                Trendy Entertainment   None
# ...                                                   ...    ...
# 119491  SEGA, Feral Interactive (Mac), Feral Interacti...   None
# 119572                                 Team17 Digital Ltd   None
# 119583  SEGA, Feral Interactive (Mac), Feral Interacti...   None
# 119634                               Tripwire Interactive   None
# 119949                                      Sandlot Games   None
#
#                                                  app_name  \
# 88384                                                None
# 88668          Europa Universalis III: Heir to the Throne
# 88779                                Booster Trooper Demo
# 88922   Warhammer 40,000: Dawn of War II - Retribution...
# 89089            Dungeon Defenders Halloween Costume Pack
# ...                                                   ...
# 119491      Total War: SHOGUN 2 - Sengoku Jidai Unit Pack
# 119572  Worms Reloaded: The "Pre-order Forts and Hats"...
# 119583      Total War: SHOGUN 2 - The Ikko Ikki Clan Pack
# 119634     Killing Floor "London's Finest" Character Pack
# 119949                            Super Granny Collection
#
#                                                     title  \
# 88384                                                None
# 88668          Europa Universalis III: Heir to the Throne
# 88779                                Booster Trooper Demo
# 88922   Warhammer 40,000: Dawn of War II - Retribution...
# 89089            Dungeon Defenders Halloween Costume Pack
# ...                                                   ...
# 119491      Total War: SHOGUN 2 - Sengoku Jidai Unit Pack
# 119572  Worms Reloaded: The "Pre-order Forts and Hats"...
# 119583      Total War: SHOGUN 2 - The Ikko Ikki Clan Pack
# 119634     Killing Floor "London's Finest" Character Pack
# 119949                            Super Granny Collection
#
#                                                       url release_date  tags  \
# 88384                      http://store.steampowered.com/         None  None
# 88668   http://store.steampowered.com/app/25806/Europa...   2009-12-15  None
# 88779   http://store.steampowered.com/app/27930/Booste...   2010-08-31  None
# 88922   http://store.steampowered.com/app/56436/Warham...   2011-02-28  None
# 89089   http://store.steampowered.com/app/202520/Dunge...   2011-11-11  None
# ...                                                   ...          ...   ...
# 119491  http://store.steampowered.com/app/34342/Total_...   2011-07-28  None
# 119572  http://store.steampowered.com/app/22630/Worms_...   2011-05-17  None
# 119583  http://store.steampowered.com/app/34348/Total_...   2011-05-26  None
# 119634  http://store.steampowered.com/app/35419/Killin...   2010-12-14  None
# 119949  http://store.steampowered.com/app/36270/Super_...   2009-07-17  None
#
#                                               reviews_url  \
# 88384                                                None
# 88668   http://steamcommunity.com/app/25806/reviews/?b...
# 88779   http://steamcommunity.com/app/27930/reviews/?b...
# 88922   http://steamcommunity.com/app/56436/reviews/?b...
# 89089   http://steamcommunity.com/app/202520/reviews/?...
# ...                                                   ...
# 119491  http://steamcommunity.com/app/34342/reviews/?b...
# 119572  http://steamcommunity.com/app/22630/reviews/?b...
# 119583  http://steamcommunity.com/app/34348/reviews/?b...
# 119634  http://steamcommunity.com/app/35419/reviews/?b...
# 119949  http://steamcommunity.com/app/36270/reviews/?b...
#
#                                                     specs  price  \
# 88384                                                None  19.99
# 88668   [Single-player, Multi-player, Downloadable Con...   9.99
# 88779                                         [Game demo]   None
# 88922                              [Downloadable Content]   0.99
# 89089                              [Downloadable Content]   0.99
# ...                                                   ...    ...
# 119491                             [Downloadable Content]   2.99
# 119572                             [Downloadable Content]   1.99
# 119583                             [Downloadable Content]   4.99
# 119634                             [Downloadable Content]   7.99
# 119949                                    [Single-player]  14.99
#
#         early_access        id  \
# 88384            0.0       NaN
# 88668            0.0   25806.0
# 88779            0.0   27930.0
# 88922            0.0   56436.0
# 89089            0.0  202520.0
# ...              ...       ...
# 119491           0.0   34342.0
# 119572           0.0   22630.0
# 119583           0.0   34348.0
# 119634           0.0   35419.0
# 119949           0.0   36270.0
#
#                                                 developer
# 88384                                                None
# 88668                                 Paradox Interactive
# 88779                                     DnS Development
# 88922   Relic Entertainment,Feral Interactive (Mac/Linux)
# 89089                                Trendy Entertainment
# ...                                                   ...
# 119491  The Creative Assembly,Feral Interactive (Mac),...
# 119572                                 Team17 Digital Ltd
# 119583  The Creative Assembly,Feral Interactive (Mac),...
# 119634                               Tripwire Interactive
# 119949                                      Sandlot Games
#
# [139 rows x 13 columns]

# %%
# También es notorio que 'title' y 'app_name' comparten la informacion
print('Cantidad de valores núlos en la columna "app_name" ',df_steam_games['app_name'].isna().sum())
print('\nCantidad de valores núlos en la columna "title" ',df_steam_games['title'].isna().sum())
# Out:
# Cantidad de valores núlos en la columna "app_name"  2
#
# Cantidad de valores núlos en la columna "title"  2050

# %%
# Rellenamos la informacion de 'title' con ''app_name' y viceversa
df_steam_games['title'].fillna(df_steam_games['app_name'], inplace=True)
df_steam_games['app_name'].fillna(df_steam_games['title'], inplace=True)

# %%
# Vemos que ahora se redujo la cantidad de datos nulos
print('Cantidad de valores núlos en la columna "app_name" ',df_steam_games['app_name'].isna().sum())
print('\nCantidad de valores núlos en la columna "title" ',df_steam_games['title'].isna().sum())
# Out:
# Cantidad de valores núlos en la columna "app_name"  2
#
# Cantidad de valores núlos en la columna "title"  2

# %%
# También 'publisher' y 'developer' comparten la informacion
print('Cantidad de valores núlos en la columna "publisher" ',df_steam_games['publisher'].isna().sum())
print('\nCantidad de valores núlos en la columna "developer" ',df_steam_games['developer'].isna().sum())
# Out:
# Cantidad de valores núlos en la columna "publisher"  8052
#
# Cantidad de valores núlos en la columna "developer"  3299

# %%
# Rellenamos la informacion de 'publisher' con 'developer' y viceversa
df_steam_games['publisher'].fillna(df_steam_games['developer'], inplace=True)
df_steam_games['developer'].fillna(df_steam_games['publisher'], inplace=True)

# Vemos que los datos nulos se han reducido
print('Cantidad de valores núlos en la columna "pubisher" ',df_steam_games['publisher'].isna().sum())
print('\nCantidad de valores núlos en la columna "developer" ',df_steam_games['developer'].isna().sum())
# Out:
# Cantidad de valores núlos en la columna "pubisher"  3234
#
# Cantidad de valores núlos en la columna "developer"  3234

# %%
# ver si 'id' tiene datos nulos
print('Cantidad de valores núlos en la columna "id" ',df_steam_games['id'].isna().sum())
# Out:
# Cantidad de valores núlos en la columna "id"  2

# %%
# ver filas donde 'id' tiene datos nulos
df_steam_games[df_steam_games['id'].isna()]
# Out:
#                                                 publisher  \
# 88384                                                None
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 88384                  None                                            None
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title  \
# 88384                                             None
# 119271  Batman: Arkham City - Game of the Year Edition
#
#                                              url release_date  \
# 88384             http://store.steampowered.com/         None
# 119271  http://store.steampowered.com/app/200260   2012-09-07
#
#                                                      tags reviews_url  \
# 88384                                                None        None
# 119271  [Action, Open World, Batman, Adventure, Stealt...        None
#
#                                                     specs  price  \
# 88384                                                None  19.99
# 119271  [Single-player, Steam Achievements, Steam Trad...  19.99
#
#         early_access  id                                   developer
# 88384            0.0 NaN                                        None
# 119271           0.0 NaN  Rocksteady Studios,Feral Interactive (Mac)

# %%
# Eliminar el registro que tiene datos nulos en 'id' con el indice 88384 pues carece de datos relevantes el url está incompleto
# y solo tiene el dato de 'price', que no dice nada
df_steam_games.drop(88384, inplace=True)

# %%
df_steam_games[df_steam_games['id'].isna()]
# Out:
#                                                 publisher  \
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title  \
# 119271  Batman: Arkham City - Game of the Year Edition
#
#                                              url release_date  \
# 119271  http://store.steampowered.com/app/200260   2012-09-07
#
#                                                      tags reviews_url  \
# 119271  [Action, Open World, Batman, Adventure, Stealt...        None
#
#                                                     specs  price  \
# 119271  [Single-player, Steam Achievements, Steam Trad...  19.99
#
#         early_access  id                                   developer
# 119271           0.0 NaN  Rocksteady Studios,Feral Interactive (Mac)

# %%
# Se identifica que el 'id' viene en la url, así que se rellena 'id' con el dato 200260 identificado
df_steam_games['id'].fillna(200260, inplace=True)

# %%
# Otra observación es con relación al tipo de dato de la columna 'id' que es flotante, pero podemos convertir a entero
df_steam_games['id'] = df_steam_games['id'].astype('int32')

# %%
df_steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32134 entries, 88310 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     28901 non-null  object
#  1   genres        31996 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         32133 non-null  object
#  4   url           32134 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31996 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30757 non-null  object
#  10  early_access  32134 non-null  float64
#  11  id            32134 non-null  int32
#  12  developer     28901 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 3.3+ MB

# %% [markdown]
# #### Revisar a partir de aquí, que columnas me son útiles

# %%
# La columna 'price' contiene valores str, así que recorremos la columna para identificar los valores
str_values = []
for price in df_steam_games['price']:
    if isinstance(price, str):
        if price not in str_values:
            str_values.append(price)

str_values
# Out:
# ['Free To Play',
#  'Free to Play',
#  'Free',
#  'Free Demo',
#  'Play for Free!',
#  'Install Now',
#  'Play WARMACHINE: Tactics Demo',
#  'Free Mod',
#  'Install Theme',
#  'Third-party',
#  'Play Now',
#  'Free HITMAN™ Holiday Pack',
#  'Play the Demo',
#  'Starting at $499.00',
#  'Starting at $449.00',
#  'Free to Try',
#  'Free Movie',
#  'Free to Use']

# %%
# Hacer un diccionario usando la lista str_values como las claves de diccionario
# y los valores serán el indice de la lista
price_dicc = {
    'Free To Play': 0,
    'Free to Play': 0,
    'Free': 0,
    'Free Demo': 0,
    'Play for Free!': 0,
    'Install Now': 0,
    'Play WARMACHINE: Tactics Demo': 0,
    'Free Mod': 0,
    'Install Theme': 0,
    'Third-party': 0,
    'Play Now': 0,
    'Free HITMAN™ Holiday Pack': 0,
    'Play the Demo': 0,
    'Starting at $499.00': 499,
    'Starting at $449.00': 449,
    'Free to Try': 0,
    'Free Movie': 0,
    'Free to Use': 0
}

# %%
# Utilizar el diccionario price_dicc para identificar los valores en str y cambiarlos por los valores correspondientes
for key, value in price_dicc.items():
    df_steam_games['price'].replace(key, value, inplace=True)

# %%
# Verificar que ya no hay valores str en 'price'
df_steam_games['price'].apply(lambda x: type(x)).value_counts()
# Out:
# price
# <class 'float'>    32134
# Name: count, dtype: int64

# %%
# Buscamos valores nulos en 'price'
df_steam_games['price'].isna().sum()
# Out:
# 1377

# %%
# Mostrar valores que no sean flotante en 'price' menores a 0
df_steam_games[~df_steam_games['price'].apply(lambda x: isinstance(x, float) and x >= 0)]
# Out:
#                  publisher                                             genres  \
# 88319            RewindApp                [Casual, Indie, Racing, Simulation]
# 88320              Qucheza          [Action, Indie, Simulation, Early Access]
# 88341       BlueLine Games                          [Casual, Indie, Strategy]
# 88342     Games by Brundle                                           [Action]
# 88344       ProjectorGames  [Action, Casual, Indie, Massively Multiplayer,...
# ...                    ...                                                ...
# 120409      Picorinne Soft                                    [Action, Indie]
# 120421         I.O.S. Team                                           [Sports]
# 120433             VersoVR  [Casual, Indie, Simulation, Sports, Early Access]
# 120435  Retro Army Limited                         [Action, Adventure, Indie]
# 120438            Riviysky                                    [Casual, Indie]
#
#                            app_name                        title  \
# 88319                          Race                         Race
# 88320               Uncanny Islands              Uncanny Islands
# 88341                   Lost Cities                  Lost Cities
# 88342      Twisted Enhanced Edition     Twisted Enhanced Edition
# 88344               Tactics Forever              Tactics Forever
# ...                             ...                          ...
# 120409               Infinos Gaiden               Infinos Gaiden
# 120421  International Online Soccer  International Online Soccer
# 120433                 Cricket Club                 Cricket Club
# 120435         The spy who shot me™         The spy who shot me™
# 120438                        BAE 2                        BAE 2
#
#                                                       url  release_date  \
# 88319      http://store.steampowered.com/app/768800/Race/    2018-01-04
# 88320   http://store.steampowered.com/app/768570/Uncan...        Soon..
# 88341   http://store.steampowered.com/app/520680/Lost_...    2018-01-01
# 88342   http://store.steampowered.com/app/690410/Twist...    2018-01-01
# 88344   http://store.steampowered.com/app/413120/Tacti...    2018-01-01
# ...                                                   ...           ...
# 120409  http://store.steampowered.com/app/771070/Infin...    2018-01-19
# 120421  http://store.steampowered.com/app/90007/Intern...    2002-01-01
# 120433  http://store.steampowered.com/app/772180/Crick...  January 2018
# 120435  http://store.steampowered.com/app/771810/The_s...    2018-10-01
# 120438    http://store.steampowered.com/app/769330/BAE_2/    2018-01-04
#
#                                                      tags  \
# 88319                 [Indie, Casual, Simulation, Racing]
# 88320   [Early Access, Action, Indie, Simulation, Surv...
# 88341   [Casual, Indie, Strategy, Card Game, Board Gam...
# 88342                 [Action, Platformer, Side Scroller]
# 88344   [Casual, Action, Massively Multiplayer, Indie,...
# ...                                                   ...
# 120409                      [Action, Indie, Shoot 'Em Up]
# 120421                                      [Sports, Mod]
# 120433  [Early Access, Indie, Casual, Simulation, Sports]
# 120435                         [Action, Adventure, Indie]
# 120438                                    [Indie, Casual]
#
#                                               reviews_url  \
# 88319   http://steamcommunity.com/app/768800/reviews/?...
# 88320   http://steamcommunity.com/app/768570/reviews/?...
# 88341   http://steamcommunity.com/app/520680/reviews/?...
# 88342   http://steamcommunity.com/app/690410/reviews/?...
# 88344   http://steamcommunity.com/app/413120/reviews/?...
# ...                                                   ...
# 120409  http://steamcommunity.com/app/771070/reviews/?...
# 120421  http://steamcommunity.com/app/90007/reviews/?b...
# 120433  http://steamcommunity.com/app/772180/reviews/?...
# 120435  http://steamcommunity.com/app/771810/reviews/?...
# 120438  http://steamcommunity.com/app/769330/reviews/?...
#
#                                                     specs  price  \
# 88319   [Single-player, Multi-player, Partial Controll...    NaN
# 88320                                     [Single-player]    NaN
# 88341   [Single-player, Multi-player, Online Multi-Pla...    NaN
# 88342            [Single-player, Full controller support]    NaN
# 88344   [Online Multi-Player, MMO, Cross-Platform Mult...    NaN
# ...                                                   ...    ...
# 120409        [Single-player, Partial Controller Support]    NaN
# 120421                 [Multi-player, Mods (require HL2)]    NaN
# 120433                                    [Single-player]    NaN
# 120435                [Single-player, Captions available]    NaN
# 120438                                    [Single-player]    NaN
#
#         early_access      id           developer
# 88319            0.0  768800           RewindApp
# 88320            1.0  768570             Qucheza
# 88341            0.0  520680      BlueLine Games
# 88342            0.0  690410    Games by Brundle
# 88344            0.0  413120      ProjectorGames
# ...              ...     ...                 ...
# 120409           0.0  771070      Picorinne Soft
# 120421           0.0   90007         I.O.S. Team
# 120433           1.0  772180             VersoVR
# 120435           0.0  771810  Retro Army Limited
# 120438           0.0  769330            Riviysky
#
# [1377 rows x 13 columns]

# %%
df_steam_games[~df_steam_games['price'].apply(lambda x: isinstance(x, float) and x >= 0)]
# Out:
#                  publisher                                             genres  \
# 88319            RewindApp                [Casual, Indie, Racing, Simulation]
# 88320              Qucheza          [Action, Indie, Simulation, Early Access]
# 88341       BlueLine Games                          [Casual, Indie, Strategy]
# 88342     Games by Brundle                                           [Action]
# 88344       ProjectorGames  [Action, Casual, Indie, Massively Multiplayer,...
# ...                    ...                                                ...
# 120409      Picorinne Soft                                    [Action, Indie]
# 120421         I.O.S. Team                                           [Sports]
# 120433             VersoVR  [Casual, Indie, Simulation, Sports, Early Access]
# 120435  Retro Army Limited                         [Action, Adventure, Indie]
# 120438            Riviysky                                    [Casual, Indie]
#
#                            app_name                        title  \
# 88319                          Race                         Race
# 88320               Uncanny Islands              Uncanny Islands
# 88341                   Lost Cities                  Lost Cities
# 88342      Twisted Enhanced Edition     Twisted Enhanced Edition
# 88344               Tactics Forever              Tactics Forever
# ...                             ...                          ...
# 120409               Infinos Gaiden               Infinos Gaiden
# 120421  International Online Soccer  International Online Soccer
# 120433                 Cricket Club                 Cricket Club
# 120435         The spy who shot me™         The spy who shot me™
# 120438                        BAE 2                        BAE 2
#
#                                                       url  release_date  \
# 88319      http://store.steampowered.com/app/768800/Race/    2018-01-04
# 88320   http://store.steampowered.com/app/768570/Uncan...        Soon..
# 88341   http://store.steampowered.com/app/520680/Lost_...    2018-01-01
# 88342   http://store.steampowered.com/app/690410/Twist...    2018-01-01
# 88344   http://store.steampowered.com/app/413120/Tacti...    2018-01-01
# ...                                                   ...           ...
# 120409  http://store.steampowered.com/app/771070/Infin...    2018-01-19
# 120421  http://store.steampowered.com/app/90007/Intern...    2002-01-01
# 120433  http://store.steampowered.com/app/772180/Crick...  January 2018
# 120435  http://store.steampowered.com/app/771810/The_s...    2018-10-01
# 120438    http://store.steampowered.com/app/769330/BAE_2/    2018-01-04
#
#                                                      tags  \
# 88319                 [Indie, Casual, Simulation, Racing]
# 88320   [Early Access, Action, Indie, Simulation, Surv...
# 88341   [Casual, Indie, Strategy, Card Game, Board Gam...
# 88342                 [Action, Platformer, Side Scroller]
# 88344   [Casual, Action, Massively Multiplayer, Indie,...
# ...                                                   ...
# 120409                      [Action, Indie, Shoot 'Em Up]
# 120421                                      [Sports, Mod]
# 120433  [Early Access, Indie, Casual, Simulation, Sports]
# 120435                         [Action, Adventure, Indie]
# 120438                                    [Indie, Casual]
#
#                                               reviews_url  \
# 88319   http://steamcommunity.com/app/768800/reviews/?...
# 88320   http://steamcommunity.com/app/768570/reviews/?...
# 88341   http://steamcommunity.com/app/520680/reviews/?...
# 88342   http://steamcommunity.com/app/690410/reviews/?...
# 88344   http://steamcommunity.com/app/413120/reviews/?...
# ...                                                   ...
# 120409  http://steamcommunity.com/app/771070/reviews/?...
# 120421  http://steamcommunity.com/app/90007/reviews/?b...
# 120433  http://steamcommunity.com/app/772180/reviews/?...
# 120435  http://steamcommunity.com/app/771810/reviews/?...
# 120438  http://steamcommunity.com/app/769330/reviews/?...
#
#                                                     specs  price  \
# 88319   [Single-player, Multi-player, Partial Controll...    NaN
# 88320                                     [Single-player]    NaN
# 88341   [Single-player, Multi-player, Online Multi-Pla...    NaN
# 88342            [Single-player, Full controller support]    NaN
# 88344   [Online Multi-Player, MMO, Cross-Platform Mult...    NaN
# ...                                                   ...    ...
# 120409        [Single-player, Partial Controller Support]    NaN
# 120421                 [Multi-player, Mods (require HL2)]    NaN
# 120433                                    [Single-player]    NaN
# 120435                [Single-player, Captions available]    NaN
# 120438                                    [Single-player]    NaN
#
#         early_access      id           developer
# 88319            0.0  768800           RewindApp
# 88320            1.0  768570             Qucheza
# 88341            0.0  520680      BlueLine Games
# 88342            0.0  690410    Games by Brundle
# 88344            0.0  413120      ProjectorGames
# ...              ...     ...                 ...
# 120409           0.0  771070      Picorinne Soft
# 120421           0.0   90007         I.O.S. Team
# 120433           1.0  772180             VersoVR
# 120435           0.0  771810  Retro Army Limited
# 120438           0.0  769330            Riviysky
#
# [1377 rows x 13 columns]

# %%
df_steam_games.sample(20)
# Out:
#                                                 publisher  \
# 113502                                TopWare Interactive
# 116350                                 Nine Tales Digital
# 104115                                   Wildcard Studios
# 118080                            Ubisoft - San Francisco
# 91723                                             Joycity
# 116261                                          Nyu Media
# 105505                                       Indie Voyage
# 88514                                         Deep Silver
# 103243                              Kalypso Media Digital
# 99561                                       Panoramik Inc
# 99981                                  Boogygames Studios
# 89786                Codemasters, Feral Interactive (Mac)
# 110271                                      Filippo Ceffa
# 101239                                         TSS Studio
# 94131                team BitClub , Sunken Treasure Games
# 102477                                         THQ Nordic
# 109318                                   Siberian Digital
# 111640                                      Bossa Studios
# 91329                         Forever Entertainment S. A.
# 119258  SEGA, Feral Interactive (Mac), Feral Interacti...
#
#                                                    genres  \
# 113502                                  [Indie, Strategy]
# 116350                                  [Indie, Strategy]
# 104115                                 [Action, Strategy]
# 118080                               [Casual, Simulation]
# 91723   [Action, Casual, Free to Play, Massively Multi...
# 116261                                           [Action]
# 105505                    [Action, Adventure, Indie, RPG]
# 88514                                            [Action]
# 103243                             [Simulation, Strategy]
# 99561   [Action, Adventure, Free to Play, Massively Mu...
# 99981                          [Adventure, Casual, Indie]
# 89786                                    [Racing, Sports]
# 110271                                    [Casual, Indie]
# 101239             [Adventure, Casual, Indie, Simulation]
# 94131                          [Action, Adventure, Indie]
# 102477                                   [Adventure, RPG]
# 109318                 [Action, Adventure, Casual, Indie]
# 111640                                       [Simulation]
# 91329                          [Adventure, Casual, Indie]
# 119258                                         [Strategy]
#
#                                                  app_name  \
# 113502                                  The Troma Project
# 116350                                       Desert Ashes
# 104115                                       Wizards:Home
# 118080         Rocksmith® 2014 – Radiohead - “Optimistic”
# 91723                      Freestyle 2: Street Basketball
# 116261  eXceed 3rd - Jade Penetrate Black Package Orig...
# 105505                                      Venture Forth
# 88514                                        Saints Row 2
# 103243                                         Dungeons 3
# 99561           Mighty Party: Academy of Enchantress Pack
# 99981                                Hidden Object - Food
# 89786                      GRID 2 - Peak Performance Pack
# 110271                                          Orbital X
# 101239                                   The Last Vampire
# 94131                                      Spaceport Hope
# 102477            Sphinx and the Cursed Mummy: Soundtrack
# 109318                                       NUKED KNIGHT
# 111640                       Worlds Adrift Island Creator
# 91329               Teddy Floppy Ear - Mountain Adventure
# 119258  Total War: Shogun 2 - Fall of the Samurai – Th...
#
#                                                     title  \
# 113502                                  The Troma Project
# 116350                                       Desert Ashes
# 104115                                       Wizards:Home
# 118080         Rocksmith® 2014 – Radiohead - “Optimistic”
# 91723                      Freestyle 2: Street Basketball
# 116261  eXceed 3rd - Jade Penetrate Black Package Orig...
# 105505                                      Venture Forth
# 88514                                        Saints Row 2
# 103243                                         Dungeons 3
# 99561           Mighty Party: Academy of Enchantress Pack
# 99981                                Hidden Object - Food
# 89786                      GRID 2 - Peak Performance Pack
# 110271                                          Orbital X
# 101239                                   The Last Vampire
# 94131                                      Spaceport Hope
# 102477            Sphinx and the Cursed Mummy: Soundtrack
# 109318                                       NUKED KNIGHT
# 111640                       Worlds Adrift Island Creator
# 91329               Teddy Floppy Ear - Mountain Adventure
# 119258  Total War: Shogun 2 - Fall of the Samurai – Th...
#
#                                                       url release_date  \
# 113502  http://store.steampowered.com/app/279640/The_T...   2015-10-28
# 116350  http://store.steampowered.com/app/324420/Deser...   2014-11-10
# 104115  http://store.steampowered.com/app/459050/Wizar...   2017-09-06
# 118080  http://store.steampowered.com/app/258380/Rocks...   2013-11-22
# 91723   http://store.steampowered.com/app/339610/Frees...   2015-04-01
# 116261  http://store.steampowered.com/app/334530/eXcee...   2014-11-26
# 105505  http://store.steampowered.com/app/501310/Ventu...   2017-06-20
# 88514   http://store.steampowered.com/app/9480/Saints_...   2009-01-28
# 103243  http://store.steampowered.com/app/493900/Dunge...   2017-10-13
# 99561   http://store.steampowered.com/app/698560/Might...   2017-08-31
# 99981   http://store.steampowered.com/app/713590/Hidde...   2017-09-25
# 89786   http://store.steampowered.com/app/221166/GRID_...   2013-07-23
# 110271  http://store.steampowered.com/app/514650/Orbit...   2016-08-18
# 101239  http://store.steampowered.com/app/766530/The_L...   2017-12-22
# 94131   http://store.steampowered.com/app/394540/Space...   2016-04-15
# 102477  http://store.steampowered.com/app/733200/Sphin...   2017-11-10
# 109318  http://store.steampowered.com/app/448250/NUKED...   2016-10-19
# 111640  http://store.steampowered.com/app/271920/World...   2016-04-28
# 91329   http://store.steampowered.com/app/340300/Teddy...   2015-01-09
# 119258  http://store.steampowered.com/app/201275/Total...   2012-05-30
#
#                                                      tags  \
# 113502                                  [Strategy, Indie]
# 116350                      [Strategy, Indie, Turn-Based]
# 104115  [Action, Strategy, Controller, Platformer, Puz...
# 118080                               [Casual, Simulation]
# 91723   [Free to Play, Basketball, Sports, Multiplayer...
# 116261  [Action, Indie, Great Soundtrack, Shooter, Sho...
# 105505                    [Action, Adventure, Indie, RPG]
# 88514   [Open World, Action, Sandbox, Character Custom...
# 103243  [Strategy, Simulation, Management, RTS, Fantas...
# 99561   [Strategy, Action, Free to Play, RPG, Massivel...
# 99981   [Casual, Indie, Adventure, Hidden Object, Puzz...
# 89786                                    [Racing, Sports]
# 110271                                    [Casual, Indie]
# 101239             [Indie, Casual, Adventure, Simulation]
# 94131   [Indie, Adventure, Platformer, Action, Pixel G...
# 102477                                   [Adventure, RPG]
# 109318  [Indie, Casual, Action, Adventure, 2D, Platfor...
# 111640  [Free to Play, Simulation, Indie, Multiplayer,...
# 91329   [Family Friendly, Casual, Adventure, Indie, Po...
# 119258                                         [Strategy]
#
#                                               reviews_url  \
# 113502  http://steamcommunity.com/app/279640/reviews/?...
# 116350  http://steamcommunity.com/app/324420/reviews/?...
# 104115  http://steamcommunity.com/app/459050/reviews/?...
# 118080  http://steamcommunity.com/app/258380/reviews/?...
# 91723   http://steamcommunity.com/app/339610/reviews/?...
# 116261  http://steamcommunity.com/app/334530/reviews/?...
# 105505  http://steamcommunity.com/app/501310/reviews/?...
# 88514   http://steamcommunity.com/app/9480/reviews/?br...
# 103243  http://steamcommunity.com/app/493900/reviews/?...
# 99561   http://steamcommunity.com/app/698560/reviews/?...
# 99981   http://steamcommunity.com/app/713590/reviews/?...
# 89786   http://steamcommunity.com/app/221166/reviews/?...
# 110271  http://steamcommunity.com/app/514650/reviews/?...
# 101239  http://steamcommunity.com/app/766530/reviews/?...
# 94131   http://steamcommunity.com/app/394540/reviews/?...
# 102477  http://steamcommunity.com/app/733200/reviews/?...
# 109318  http://steamcommunity.com/app/448250/reviews/?...
# 111640  http://steamcommunity.com/app/271920/reviews/?...
# 91329   http://steamcommunity.com/app/340300/reviews/?...
# 119258  http://steamcommunity.com/app/201275/reviews/?...
#
#                                                     specs  price  \
# 113502                                    [Single-player]   6.99
# 116350  [Single-player, Multi-player, Steam Achievemen...   4.99
# 104115  [Single-player, Shared/Split Screen, Full cont...   4.99
# 118080  [Single-player, Shared/Split Screen, Downloada...   2.99
# 91723   [Online Multi-Player, MMO, Online Co-op, Steam...   0.00
# 116261  [Single-player, Downloadable Content, Steam Tr...   9.99
# 105505  [Single-player, Steam Achievements, Partial Co...   9.99
# 88514                        [Single-player, Steam Cloud]   9.99
# 103243  [Single-player, Multi-player, Co-op, Cross-Pla...  39.99
# 99561   [Single-player, Multi-player, MMO, Cross-Platf...   9.99
# 99981                                     [Single-player]   1.99
# 89786   [Single-player, Multi-player, Downloadable Con...   4.99
# 110271  [Single-player, Steam Achievements, Steam Trad...   2.99
# 101239               [Single-player, Steam Trading Cards]   0.99
# 94131   [Single-player, Steam Achievements, Steam Trad...   1.99
# 102477              [Single-player, Downloadable Content]   4.99
# 109318  [Single-player, Steam Achievements, Steam Trad...   4.99
# 111640       [Single-player, Steam Workshop, Steam Cloud]   0.00
# 91329   [Single-player, Steam Trading Cards, Steam Cloud]   4.99
# 119258  [Single-player, Multi-player, Co-op, Downloada...   2.99
#
#         early_access      id  \
# 113502           0.0  279640
# 116350           0.0  324420
# 104115           0.0  459050
# 118080           0.0  258380
# 91723            0.0  339610
# 116261           0.0  334530
# 105505           0.0  501310
# 88514            0.0    9480
# 103243           0.0  493900
# 99561            0.0  698560
# 99981            0.0  713590
# 89786            0.0  221166
# 110271           0.0  514650
# 101239           0.0  766530
# 94131            0.0  394540
# 102477           0.0  733200
# 109318           0.0  448250
# 111640           0.0  271920
# 91329            0.0  340300
# 119258           0.0  201275
#
#                                                 developer
# 113502                                          Nekrosoft
# 116350                                 Nine Tales Digital
# 104115                                   Wildcard Studios
# 118080                            Ubisoft - San Francisco
# 91723                                             Joycity
# 116261                                       Tennen-sozai
# 105505                                    Arclight Worlds
# 88514                                            Volition
# 103243                                 Realmforge Studios
# 99561                                       Panoramik Inc
# 99981                                  Boogygames Studios
# 89786          Codemasters Racing,Feral Interactive (Mac)
# 110271                                      Filippo Ceffa
# 101239                                         TSS Studio
# 94131                                        team BitClub
# 102477                                 Eurocom,THQ Nordic
# 109318                                        Nuked Games
# 111640                                      Bossa Studios
# 91329                         Forever Entertainment S. A.
# 119258  The Creative Assembly,Feral Interactive (Mac),...

# %%
df_steam_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32134 entries, 88310 to 120444
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publisher     28901 non-null  object
#  1   genres        31996 non-null  object
#  2   app_name      32133 non-null  object
#  3   title         32133 non-null  object
#  4   url           32134 non-null  object
#  5   release_date  30068 non-null  object
#  6   tags          31996 non-null  object
#  7   reviews_url   32133 non-null  object
#  8   specs         31465 non-null  object
#  9   price         30757 non-null  float64
#  10  early_access  32134 non-null  float64
#  11  id            32134 non-null  int32
#  12  developer     28901 non-null  object
# dtypes: float64(2), int32(1), object(10)
# memory usage: 3.3+ MB
